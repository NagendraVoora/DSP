# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
sns.distplot([0, 1, 2, 3, 4, 5])

# %%
sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

# %%
sns.distplot([0, 1, 2, 3, 4, 5], kde=False)

# %%
sns.distplot([0, 1, 2, 3, 4, 5], color="green")

# %%
data=pd.read_csv("sample.csv")

# %%
data
# Out:
#     NAME   AGE   DEPT  SALARY
# 0    MARK   23    CSE   12000
# 1   MELLO   34    ECE   23000
# 2  JOSEPH   23     ME  340000
# 3    BERG   54    CSE   10000
# 4   KOHLI   23  CIVIL   23233
# 5    REMS   43    ECE   23432

# %%
sns.regplot(x="AGE",y="SALARY",data=data)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
help(WordCloud)
# Out:
# Help on class WordCloud in module wordcloud.wordcloud:
#
# class WordCloud(builtins.object)
#  |  WordCloud(font_path=None, width=400, height=200, margin=2, ranks_only=None, prefer_horizontal=0.9, mask=None, scale=1, color_func=None, max_words=200, min_font_size=4, stopwords=None, random_state=None, background_color='black', max_font_size=None, font_step=1, mode='RGB', relative_scaling='auto', regexp=None, collocations=True, colormap=None, normalize_plurals=True, contour_width=0, contour_color='black', repeat=False, include_numbers=False, min_word_length=0, collocation_threshold=30)
#  |
#  |  Word cloud object for generating and drawing.
#  |
#  |  Parameters
#  |  ----------
#  |  font_path : string
#  |      Font path to the font that will be used (OTF or TTF).
#  |      Defaults to DroidSansMono path on a Linux machine. If you are on
#  |      another OS or don't have this font, you need to adjust this path.
#  |
#  |  width : int (default=400)
#  |      Width of the canvas.
# ...

# %%
k=WordCloud().generate("AA B C D E AA B C AA B C D D D E E E E E E E E E")
plt.imshow(k)

# %%
k=WordCloud(background_color="white",height=1000,width=1000).generate("AA B C D E AA B C AA B C D D D E E E E E E E E E")
plt.imshow(k)

# %%
k=WordCloud(background_color="white").generate("AA B C D E AA B C AA B C D D D E E E E E E E E E")
plt.imshow(k)

# %%
k=WordCloud().generate("AA B C D E AA B C AA B C D D D E E E E E E E E E")
plt.imshow(k)

# %%
k=WordCloud(background_color="green").generate("AA B C D E AA B C AA B C D D D E E E E E E E E E")
plt.imshow(k)

# %%
import seaborn as sns
help(sns.distplot)
# Out:
# Help on function distplot in module seaborn.distributions:
#
# distplot(a, bins=None, hist=True, kde=True, rug=False, fit=None, hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None, color=None, vertical=False, norm_hist=False, axlabel=None, label=None, ax=None)
#     Flexibly plot a univariate distribution of observations.
#
#     This function combines the matplotlib ``hist`` function (with automatic
#     calculation of a good default bin size) with the seaborn :func:`kdeplot`
#     and :func:`rugplot` functions. It can also fit ``scipy.stats``
#     distributions and plot the estimated PDF over the data.
#
#     Parameters
#     ----------
#
#     a : Series, 1d-array, or list.
#         Observed data. If this is a Series object with a ``name`` attribute,
#         the name will be used to label the data axis.
#     bins : argument for matplotlib hist(), or None, optional
#         Specification of hist bins. If unspecified, as reference rule is used
# ...

# %%
help(sns.regplot)
# Out:
# Help on function regplot in module seaborn.regression:
#
# regplot(x, y, data=None, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, seed=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=True, dropna=True, x_jitter=None, y_jitter=None, label=None, color=None, marker='o', scatter_kws=None, line_kws=None, ax=None)
#     Plot data and a linear regression model fit.
#
#     There are a number of mutually exclusive options for estimating the
#     regression model. See the :ref:`tutorial <regression_tutorial>` for more
#     information.
#
#     Parameters
#     ----------
#     x, y: string, series, or vector array
#         Input variables. If strings, these should correspond with column names
#         in ``data``. When pandas objects are used, axes will be labeled with
#         the series name.
#     data : DataFrame
# ...
